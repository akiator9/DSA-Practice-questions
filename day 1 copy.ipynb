# %%
i = 0
while i<=4:
    print('0'*6)
    i = i+1
# Out:
# 000000
# 000000
# 000000
# 000000
# 000000

# %%
i = 1
while i<=4:
    print('0'*i)
    i =i+1
# Out:
# 0
# 00
# 000
# 0000

# %%
i =1
while i <= 5:
    print(f'{i}'*(i))
    i = i+1
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
i = 5
while i >=1:
    print('*'*i)
    i =i-1
# Out:
# *****
# ****
# ***
# **
# *

# %%
i = 1
while i <=4:
    tmp = ''
    j = 1
    while j <=i:
        tmp = tmp + str(j)
        j = j+1
    print(tmp)
    i = i+1
# Out:
# 1
# 12
# 123
# 1234

# %%
for i in range(1,5,1):
    tmp = ''
    for j in range(1,i+1):
        tmp = tmp+str(j)
    print(tmp)
# Out:
# 1
# 12
# 123
# 1234

# %%
i = 1
while i <=4:
    print((4-i)*' '+'*'*i)
    i = i+1
# Out:
#    *
#   **
#  ***
# ****

# %%
i = 1
while i <= 4:
    print((4-i)*" "+((2*i)-1)*'*'+(4-i)*' ')
    i=i+1
# Out:
#    *
#   ***
#  *****
# *******
