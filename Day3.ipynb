# %% [markdown]
# For N = 4
# print
# 4444
# 333
# 22
# 1

# %%
N = 4
i=1
while i <=4:
    str1 = ''
    for j in range (1,i+1):
        str1 = str1+str(j)
    print((' '*(N-i))+str1)
    i = i+1

# %%
For N = 4
Print 
   1
  12
 123
1234

# %%
i = 4
while i>0:
    print(f'{i}'*i)
    i = i-1
